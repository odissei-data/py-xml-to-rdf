# %%
import xmltodict
import csv

# %%
xmlfile = 'ODISSEI_Full_Export_20210924/0b01e410800a0eb5_PS Agrarische dienstverlening_2011-01-01.dsc'

# %%
csvfile = 'test.csv'

# %%
with open(xmlfile) as fd:
    doc = xmltodict.parse(fd.read())

# %%
a = doc['Dataontwerpversies']['Versie']

# %%
with open(csvfile, mode ='r')as csv_file:
   
  # reading the CSV file
  csvFile = csv.reader(csv_file)
 
  # displaying the contents of the CSV file
  for lines in csvFile:
        command_1 = lines[0]

# %%
print(a['Dataontwerp'])
# Out:
# OrderedDict([('Id', '0b01e410800a0eb5'), ('Dataontwerpgroeppad', 'Economie, bedrijven en nationale rekeningen/Industrie, energie en bouw/Milieu en argrarische dienstverlening (EDMA)/Productiestatistiek milieu en argrarische dienstverlening'), ('NaamInDscCatalogus', OrderedDict([('@xsi:nil', 'true')])), ('UniekeNaam', OrderedDict([('@xsi:nil', 'true')])), ('Beschrijving', 'Landelijke statistische uitkomsten over het personeel, de exploitatie en de productie van bedrijven op het terrein van Agrarische dienstverlening'), ('VerkorteSchrijfwijzeNaamDataontwerp', 'PS Agrarische dienstverlening'), ('PrivacyGevoeligheid', OrderedDict([('@xsi:nil', 'true')])), ('BeschrijvingVanDePopulatie', 'Bedrijfseenheden'), ('NederlandstaligePublicatietekst', OrderedDict([('@xsi:nil', 'true')])), ('EngelstaligePublicatietekst', OrderedDict([('@xsi:nil', 'true')])), ('Eigenaar', OrderedDict([('@xsi:nil', 'true')])), ('GebruikteMethodologie', OrderedDict([('@xsi:nil', 'true')])), ('TypeVerslagperiode', 'Jaa
# ...

# %%
print(b)
# Out:
# 0b01e410800a0eb5

# %%
print(a)
# Out:
# OrderedDict([('Id', '0b01e410800a0eb5'), ('Dataontwerpgroeppad', 'Economie, bedrijven en nationale rekeningen/Industrie, energie en bouw/Milieu en argrarische dienstverlening (EDMA)/Productiestatistiek milieu en argrarische dienstverlening'), ('NaamInDscCatalogus', OrderedDict([('@xsi:nil', 'true')])), ('UniekeNaam', OrderedDict([('@xsi:nil', 'true')])), ('Beschrijving', 'Landelijke statistische uitkomsten over het personeel, de exploitatie en de productie van bedrijven op het terrein van Agrarische dienstverlening'), ('VerkorteSchrijfwijzeNaamDataontwerp', 'PS Agrarische dienstverlening'), ('PrivacyGevoeligheid', OrderedDict([('@xsi:nil', 'true')])), ('BeschrijvingVanDePopulatie', 'Bedrijfseenheden'), ('NederlandstaligePublicatietekst', OrderedDict([('@xsi:nil', 'true')])), ('EngelstaligePublicatietekst', OrderedDict([('@xsi:nil', 'true')])), ('Eigenaar', OrderedDict([('@xsi:nil', 'true')])), ('GebruikteMethodologie', OrderedDict([('@xsi:nil', 'true')])), ('TypeVerslagperiode', 'Jaa
# ...

# %%
list_command_1 = command_1.split('/')

# %%
def latex_repr(r):
    def wrapper(f):
        f.latex = r
        return f
    return wrapper

# %%
@latex_repr(r'$ax^2 + bx + c$')
def func(x, a, b, c):
    return a*x**2 + b*x + c

# %%
func = latex_repr(r'$ax^2 + bx + c$')(func)

# %%
print(func.latex)
# Out:
# $ax^2 + bx + c$

# %%
setattr(doc, ['Dataontwerpversies'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-df633d2d0301> in <module>
# ----> 1 setattr(doc, ['Dataontwerpversies'])
#
# TypeError: setattr expected 3 arguments, got 2
